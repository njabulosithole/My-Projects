# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
plt.rcParams['figure.figsize'] = (12.0, 9.0)

# %%
data = pd.read_excel('data.xlsx')

# %%
data.head()
# Out:
#            X          Y
# 0  32.502345  31.707006
# 1  53.426804  68.777596
# 2  61.530358  62.562382
# 3  47.475640  71.546632
# 4  59.813208  87.230925

# %%
X = data.iloc[:, 0]
Y = data.iloc[:, 1]
plt.scatter(X, Y)
plt.show()

# %%
data.head()
# Out:
#            X          Y
# 0  32.502345  31.707006
# 1  53.426804  68.777596
# 2  61.530358  62.562382
# 3  47.475640  71.546632
# 4  59.813208  87.230925

# %% [markdown]
# Building the model

# %%
m = 0
c = 0
a = 0
learnig_rate = 0.0001  # The learning Rate
epochs = 1000  # The number of iterations to perform gradient descent

n = float(len(X)) 
print(n, " elements of X")

# Performing Gradient Descent 
for i in range(epochs): 
    Y_pred = m*X + c  # The current predicted value of Y
    D_m = (-2/n) * sum(X * (Y - Y_pred))  # Derivative wrt m
    D_c = (-2/n) * sum(Y - Y_pred)  # Derivative wrt c
    m = m - learnig_rate * D_m  # Update m
    c = c - learnig_rate * D_c  # Update c
    
print ("M = ",m," C = ", c)
# Out:
# 100.0  elements of X
# M =  1.4777440851894448  C =  0.08893651993741342

# %% [markdown]
# Make prediitons

# %%
Y_pred = m*X + c

plt.scatter(X,Y)
plt.plot([min(X), max(X)], [min(Y_pred), max(Y_pred)], color='purple' )
plt.show()

# %%
print("y = mx +c : ", Y_pred)
# Out:
# y = mx +c :  0     48.119085
# 1     79.040080
# 2     91.015059
# 3     70.245782
# 4     88.477551
#         ...
# 95    74.020731
# 96    72.852709
# 97    74.034624
# 98    71.242106
# 99    37.222406
# Name: X, Length: 100, dtype: float64

# %%
print(m , c)
# Out:
# 1.4777440851894448 0.08893651993741342

# %% [markdown]
# feeding the model the value of X from the data

# %%
a = int(input(" enter the index value of X : "))

b = X[a]

print("x is :",b, " m = ",m, "c = ", c)

y = m*b +c
print("y = m*x +c ", y)
# Out:
#  enter the index value of X : 98
# x is : 48.14985889102886  m =  1.4777440851894448 c =  0.08893651993741342
# y = m*x +c  71.24210569886172

# %%
y = m*b +c
print(y)
# Out:
# 88.477550665316

# %%
import
